# %%
# Exercise:
# 1. Print your name
# 2. Print a greeting like "Good Morning!"
# YOUR CODE BELOW

# %%
# Exercise:
# 1. Create variables for your favorite food and your age, then print them
# 2. Assign the same value to three variables and print them
# YOUR CODE BELOW

# %%
# Exercise:
# 1. Create one variable of each type above and print their values
# 2. Use the type() function to check their types
# YOUR CODE BELOW
my_int = 25
my_float = 7.5
my_str = "Python is fun!"
my_bool = False
print(my_int)
print(my_float)
print(my_str)
print(my_bool)
print(type(my_int))
print(type(my_float))
print(type(my_str))
print(type(my_bool))

# %%
# Exercise:
# 1. Ask the user for their favorite color and print a message using that color
# 2. Ask the user for a number, convert it to int, and print it multiplied by 2
# YOUR CODE BELOW
favourite_color = input("what is your favourite color")
print("My favourite color is:" ,  favourite_color)

number = input("Enter the number")
print(int(number))
print(number * 2)

# %%
# Exercise:
# 1. Ask the user for their name and age, then print a message using both + and f-strings
# YOUR CODE BELOW
name = "Taylor"
age = 19
height = 5.9
print(f"my name is {name}. I am {age} old and my height is {height} meters")

# %%
# Exercise:
# 1. Create a Boolean variable to check if a number entered by the user is greater than 10
# 2. Use an if statement to print "Big number" or "Small number"
# YOUR CODE BELOW

num = int(input("Enter the number"))
is_big = num > 10
if is_big:
  print("big number")
else:
  print("small number")

# %%
# Exercise:
# 1. Assign your name, age, and favorite color to three variables in one line
# 2. Assign the value 0 to three variables at once and print them
# YOUR CODE BELOW
name, age, favourite_color = "Hasen", 25, "blue"
print(name)
print(age)
print(favourite_color)


a = b = c = 0
print(a)
print(b)
print(c)

# %%
# Exercise:
# 1. Ask the user for a number and print whether it is even or odd
# YOUR CODE BELOW
a = 18
b = 3
remainder = a%b
print(remainder)
